# %%
import deidHelpers as deid
import large_image

# %%
pip install -r requirements.txt
# Out:
# ...
#   Using cached large_image-1.28.1-py3-none-any.whl (94 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: large-image
#     Found existing installation: large-image 1.29.0
#     Uninstalling large-image-1.29.0:
#       Successfully uninstalled large-image-1.29.0
#   DEPRECATION: pyvips is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for pyvips ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
deid.deid_workflow()
# Out:
# Sample slide data/CMU-2-backup.svs
# In tempdir

# %%
ts = large_image.open('./data/CMU-2-backup.svs')

# %%
import large_image
